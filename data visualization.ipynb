# %%
import seaborn as ans
import matplotlib.pyplot as plt
import pandas as pd

# %%
df= pd.read_csv(r"C:\Users\91955\Downloads\Dataset\heart.csv", sep=',')

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
ans.lineplot(df)
# Out:
# <Axes: >

# %%
ans.barplot(x='sex', y='chol', data=df)
# Out:
# <Axes: xlabel='sex', ylabel='chol'>

# %%
correlation_matrix=df[['age','cp','chol']].corr()
ans.heatmap(correlation_matrix,annot=True)
# Out:
# <Axes: >

# %%
ans.boxplot(x='sex' ,y='chol',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='chol'>

# %%
# !pip install squarify

# %%
import squarify
groupby_df=df.groupby('cp')[['sex']].sum()

groupby_df
# Out:
#     sex
# cp
# 0   104
# 1    32
# 2    52
# 3    19

# %%
squarify.plot(groupby_df.values,
             label=groupby_df.index)
# Out:
# <Axes: >

# %%
ans.violinplot(x='sex' , y='output', data=df )
# Out:
# <Axes: xlabel='sex', ylabel='output'>

# %%
ans.histplot(x='age', y='chol' ,data=df, bins=20)
# Out:
# <Axes: xlabel='age', ylabel='chol'>
